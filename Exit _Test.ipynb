# %%
#import all libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset

# %%
data=pd.read_csv("data_car.csv")

# %%
# to find first 5 rows
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
# to find no of rows and columns
data.shape
# Out:
# (11914, 16)

# %%
# to get description of data in each columns
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %%
# to get informations such as no of columns,data types,null values,range index etc
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 1.5+ MB

# %%
#to find null values
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#to check duplicated rows
duplicates=data[data.duplicated()]
duplicates
# Out:
#          Make     Model  Year             Engine Fuel Type  Engine HP  \
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# 24       Audi       100  1993             regular unleaded      172.0
# 25       Audi       100  1993             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11481  Suzuki      X-90  1998             regular unleaded       95.0
# 11603   Volvo      XC60  2017             regular unleaded      302.0
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 14                  6.0            MANUAL   rear wheel drive              2.0
# 18                  6.0            MANUAL  front wheel drive              4.0
# 20                  6.0            MANUAL  front wheel drive              4.0
# 24                  6.0            MANUAL  front wheel drive              4.0
# 25                  6.0            MANUAL  front wheel drive              4.0
# ...                 ...               ...                ...              ...
# 11481               4.0            MANUAL   four wheel drive              2.0
# 11603               4.0         AUTOMATIC    all wheel drive              4.0
# 11604               4.0         AUTOMATIC  front wheel drive              4.0
# 11708               6.0         AUTOMATIC    all wheel drive              4.0
# 11717               6.0         AUTOMATIC  front wheel drive              4.0
#
#                     Market Category Vehicle Size Vehicle Style  highway MPG  \
# 14               Luxury,Performance      Compact         Coupe           28
# 18                           Luxury      Midsize         Sedan           24
# 20                           Luxury      Midsize         Sedan           24
# 24                           Luxury      Midsize         Sedan           24
# 25                           Luxury      Midsize         Sedan           24
# ...                             ...          ...           ...          ...
# 11481                           NaN      Compact       2dr SUV           26
# 11603  Crossover,Luxury,Performance      Midsize       4dr SUV           29
# 11604              Crossover,Luxury      Midsize       4dr SUV           30
# 11708                     Crossover      Midsize       4dr SUV           22
# 11717                     Crossover      Midsize       4dr SUV           22
#
#        city mpg  Popularity   MSRP
# 14           19        3916  31500
# 18           17        3105   2000
# 20           17        3105   2000
# 24           17        3105   2000
# 25           17        3105   2000
# ...         ...         ...    ...
# 11481        22         481   2000
# 11603        20         870  46350
# 11604        23         870  40950
# 11708        15         481  29149
# 11717        16         481  27499
#
# [715 rows x 16 columns]

# %%
#to remove duplicated rows
data.drop_duplicates(inplace=True)

# %%
#again check for any duplicated rows present
duplicates=data[data.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %% [markdown]
# # EDA

# %% [markdown]
# Univariate Analysis

# %%
freqgraph=data.select_dtypes(include=['float','int','object'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
# Group the data by "Year" and calculate the average "MSRP" for each year
data_grouped = data.groupby('Year')['MSRP'].mean().reset_index()

# Create a bar plot
plt.bar(data_grouped['Year'], data_grouped['MSRP'])

# Set the title and labels
plt.title('Bivariate Analysis: Year vs MSRP')
plt.xlabel('Year')
plt.ylabel('Average MSRP')

# Display the plot
plt.show()

# %%
# Group the data by "Year" and calculate the average "MSRP" for each year
data_grouped = data.groupby('Year')['Popularity'].mean().reset_index()

# Create a bar plot
plt.bar(data_grouped['Year'], data_grouped['Popularity'])

# Set the title and labels
plt.title('Bivariate Analysis: Year vs Popularity')
plt.xlabel('Year')
plt.ylabel('Average Popularity')

# Display the plot
plt.show()

# %%
# Group the data by "Year" and calculate the average "MSRP" for each year
data_grouped = data.groupby('Transmission Type')['MSRP'].mean().reset_index()

# Create a bar plot
plt.bar(data_grouped['Transmission Type'], data_grouped['MSRP'])

# Set the title and labels
plt.title('Bivariate Analysis: Transmission Type vs MSRP')
plt.xlabel('Transmission Type')
plt.ylabel('Average MSRP')
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Group the data by "Year" and calculate the average "MSRP" for each year
data_grouped = data.groupby('Vehicle Style')['MSRP'].mean().reset_index()

# Create a bar plot
plt.bar(data_grouped['Vehicle Style'], data_grouped['MSRP'])

# Set the title and labels
plt.title('Bivariate Analysis: Vehicle Style vs MSRP')
plt.xlabel('Vehicle Style')
plt.ylabel('Average MSRP')
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
corrmatrix=data.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,annot=True,vmin=0.5,vmax=1,linewidth=0.3,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Removal Of Null Values

# %%
# Fill missing values in "Engine Fuel Type" column with the mode
x1 = data["Engine Fuel Type"].mode()[0]
data["Engine Fuel Type"].fillna(x1, inplace=True)

# Fill missing values in "Engine HP" column with the median
y1 = data["Engine HP"].median()
data["Engine HP"].fillna(y1, inplace=True)

# Fill missing values in "Engine Cylinders" column with the mode
z1 = data["Engine Cylinders"].mode()[0]
data["Engine Cylinders"].fillna(z1, inplace=True)

# Fill missing values in "Number of Doors" column with the mode
x2 = data["Number of Doors"].mode()[0]
data["Number of Doors"].fillna(x2, inplace=True)

# Fill missing values in "Market Category" column with the mode
y2 = data["Market Category"].mode()[0]
data["Market Category"].fillna(y2, inplace=True)

# %%
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from scipy import stats
le=LabelEncoder()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Make'] = le.fit_transform(data['Make'])
data['Model'] = le.fit_transform(data['Model'])
data['Engine Fuel Type'] = le.fit_transform(data['Engine Fuel Type'])
data['Transmission Type'] = le.fit_transform(data['Transmission Type'])
data['Driven_Wheels'] = le.fit_transform(data['Driven_Wheels'])
data['Market Category'] = le.fit_transform(data['Market Category'])
data['Vehicle Size'] = le.fit_transform(data['Vehicle Size'])
data['Vehicle Style'] = le.fit_transform(data['Vehicle Style'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11199 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11199 non-null  int32
#  1   Model              11199 non-null  int32
#  2   Year               11199 non-null  int64
#  3   Engine Fuel Type   11199 non-null  int32
#  4   Engine HP          11199 non-null  float64
#  5   Engine Cylinders   11199 non-null  float64
#  6   Transmission Type  11199 non-null  int32
#  7   Driven_Wheels      11199 non-null  int32
#  8   Number of Doors    11199 non-null  float64
#  9   Market Category    11199 non-null  int32
#  10  Vehicle Size       11199 non-null  int32
#  11  Vehicle Style      11199 non-null  int32
#  12  highway MPG        11199 non-null  int64
#  13  city mpg           11199 non-null  int64
#  14  Popularity         11199 non-null  int64
#  15  MSRP               11199 non-null  int64
# dtypes: float64(3), int32(8), int64(5)
# memory usage: 1.1 MB

# %%
#boxplot for outlier detection
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %% [markdown]
# Treating Outliers

# %%
#year
IQR=stats.iqr(data.Year,interpolation="midpoint")
IQR
# Out:
# 8.0

# %%
Q1=data.Year.quantile(0.25)
Q3=data.Year.quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (1996.0, 2028.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data.Year>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data.Year<min_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 27        3      2  1994                 9      172.0               6.0
# 28        3      2  1994                 9      172.0               6.0
# 29        3      2  1994                 9      172.0               6.0
# 30        3      2  1994                 9      172.0               6.0
# 31        3      2  1994                 9      172.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11197    15    846  1994                 9      200.0               8.0
# 11199    15    846  1995                 9      165.0               6.0
# 11200    15    846  1995                 9      165.0               6.0
# 11201    15    846  1995                 9      165.0               6.0
# 11378     0    859  1994                 9      176.0               5.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 27                     1              2              4.0               63
# 28                     3              0              4.0               63
# 29                     3              2              4.0               63
# 30                     1              2              4.0               63
# 31                     1              0              4.0               63
# ...                  ...            ...              ...              ...
# 11197                  1              3              3.0                0
# 11199                  1              3              3.0                0
# 11200                  1              3              3.0                0
# 11201                  1              3              3.0                0
# 11378                  3              2              4.0               63
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity  MSRP
# 27                2             15           21        16        3105  2000
# 28                2             14           22        16        3105  2000
# 29                2             14           22        17        3105  2000
# 30                2             14           22        16        3105  2000
# 31                2             15           21        16        3105  2000
# ...             ...            ...          ...       ...         ...   ...
# 11197             1              5           16        12         549  2000
# 11199             2              5           20        15         549  2000
# 11200             2              5           15        13         549  2000
# 11201             0              5           20        15         549  2000
# 11378             2             14           24        18         204  2000
#
# [246 rows x 16 columns]

# %%
data.loc[data['Year']<min_limit,'Year']=np.median(data.Year)

# %%
data.loc[data.Year<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#Engine Fuel Type
IQR=stats.iqr(data['Engine Fuel Type'],interpolation="midpoint")
IQR
# Out:
# 1.0

# %%
Q1=data['Engine Fuel Type'].quantile(0.25)
Q3=data['Engine Fuel Type'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (6.5, 10.5)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['Engine Fuel Type']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Engine Fuel Type']<min_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 64       10      7  2015                 4      184.0               4.0
# 65       10      7  2015                 4      184.0               4.0
# 66       10      7  2015                 4      295.0               6.0
# 67       10      7  2015                 4      184.0               4.0
# 68       10      7  2015                 4      184.0               4.0
# ...     ...    ...   ...               ...        ...               ...
# 11874    15    893  2016                 4      355.0               8.0
# 11876    15    893  2017                 4      355.0               8.0
# 11877    15    893  2017                 4      355.0               8.0
# 11879    15    893  2017                 4      355.0               8.0
# 11880    15    893  2017                 4      355.0               8.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 64                     1              2              4.0               41
# 65                     1              2              4.0               41
# 66                     1              0              4.0               48
# 67                     1              2              4.0               41
# 68                     1              2              4.0               48
# ...                  ...            ...              ...              ...
# 11874                  1              1              4.0               48
# 11876                  1              3              4.0               48
# 11877                  1              1              4.0               48
# 11879                  1              1              4.0               48
# 11880                  1              3              4.0               48
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 64                2             14           36        23        1013  25170
# 65                2             14           36        23        1013  23950
# 66                2             14           29        18        1013  29370
# 67                2             14           36        23        1013  21995
# 68                2             14           36        23        1013  26625
# ...             ...            ...          ...       ...         ...    ...
# 11874             1              3           22        16         549  60000
# 11876             1              3           23        16         549  57315
# 11877             1              3           22        16         549  51530
# 11879             1              3           22        16         549  60315
# 11880             1              3           23        16         549  48530
#
# [1190 rows x 16 columns]

# %%
data.loc[data['Engine Fuel Type']<min_limit,['Engine Fuel Type']]=np.median(data['Engine Fuel Type'])

# %%
data.loc[data['Engine Fuel Type']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#Engine HP
IQR=stats.iqr(data['Engine HP'],interpolation="midpoint")
IQR
# Out:
# 131.0

# %%
Q1=data['Engine HP'].quantile(0.25)
Q3=data['Engine HP'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (-24.5, 499.5)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['Engine HP']>max_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 466      13     29  2013                 9      562.0               8.0
# 467      13     29  2013                 9      562.0               8.0
# 468      13     29  2014                 9      562.0               8.0
# 469      13     29  2014                 9      597.0               8.0
# 470      13     29  2014                 9      562.0               8.0
# ...     ...    ...   ...               ...        ...               ...
# 11509     4    873  2016                 9      567.0               8.0
# 11510     4    873  2017                 9      567.0               8.0
# 11523     4    875  2015                 9      567.0               8.0
# 11524     4    875  2016                 9      567.0               8.0
# 11525     4    875  2017                 9      567.0               8.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 466                    0              3              2.0               30
# 467                    0              3              2.0               30
# 468                    0              3              2.0               30
# 469                    0              3              2.0               30
# 470                    0              3              2.0               30
# ...                  ...            ...              ...              ...
# 11509                  1              0              4.0                4
# 11510                  1              0              4.0                4
# 11523                  1              0              4.0                4
# 11524                  1              0              4.0                4
# 11525                  1              0              4.0                4
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 466               0              6           17        13        2774  257412
# 467               0              8           17        13        2774  233509
# 468               0              8           17        13        2774  233509
# 469               0              8           17        13        2774  288000
# 470               0              6           17        13        2774  257412
# ...             ...            ...          ...       ...         ...     ...
# 11509             2              3           19        14        3916   98800
# 11510             2              3           19        14        3916   98800
# 11523             2              3           19        14        3916  102100
# 11524             2              3           19        14        3916  102200
# 11525             2              3           19        14        3916  102200
#
# [502 rows x 16 columns]

# %%
data.loc[data['Engine HP']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Engine HP']>max_limit,['Engine HP']]=np.median(data['Engine HP'])

# %%
data.loc[data['Engine HP']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#Engine Cylinders
IQR=stats.iqr(data['Engine Cylinders'],interpolation="midpoint")
IQR
# Out:
# 2.0

# %%
Q1=data['Engine Cylinders'].quantile(0.25)
Q3=data['Engine Cylinders'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (1.0, 9.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['Engine Cylinders']>max_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 460      13     28  2001                 9      442.0              12.0
# 461      13     28  2001                 9      442.0              12.0
# 462      13     28  2002                 9      442.0              12.0
# 463      13     28  2002                 9      442.0              12.0
# 464      13     28  2003                 9      442.0              12.0
# ...     ...    ...   ...               ...        ...               ...
# 11394     2    861  2012                 9      490.0              12.0
# 11395     2    861  2012                 9      490.0              12.0
# 11448    38    867  2014                 9      239.0              12.0
# 11449    38    867  2015                 9      239.0              12.0
# 11450    38    867  2016                 9      239.0              12.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 460                    1              3              2.0               30
# 461                    3              3              2.0               30
# 462                    1              3              2.0               30
# 463                    3              3              2.0               30
# 464                    1              3              2.0               30
# ...                  ...            ...              ...              ...
# 11394                  1              3              2.0               30
# 11395                  1              3              2.0               30
# 11448                  1              3              2.0               32
# 11449                  1              3              2.0               32
# 11450                  1              3              2.0               32
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 460               0              8           14         9        2774  223970
# 461               0              8           15         9        2774  219775
# 462               0              8           14         9        2774  228625
# 463               0              8           15         9        2774  224585
# 464               0              8           14         9        2774  228625
# ...             ...            ...          ...       ...         ...     ...
# 11394             2              8           18        13         259  208295
# 11395             2              6           18        13         259  223295
# 11448             1              8           21        13          86  284900
# 11449             1              8           21        13          86  294025
# 11450             1              8           21        13          86  304350
#
# [296 rows x 16 columns]

# %%
data.loc[data['Engine Cylinders']<min_limit]
# Out:
#       Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 539     12     39  2015                 9      239.0               0.0
# 540     12     39  2016                 9      239.0               0.0
# 541     12     39  2017                 9      239.0               0.0
# 1680    31    133  2015                 9      177.0               0.0
# 1681    31    133  2016                 9      177.0               0.0
# 1682    31    133  2017                 9      177.0               0.0
# 4705    18    354  2013                 9      239.0               0.0
# 4706    18    354  2014                 9      239.0               0.0
# 4785    14    359  2015                 9      239.0               0.0
# 4789    14    359  2016                 9      239.0               0.0
# 4798    14    359  2017                 9      239.0               0.0
# 5790     4    907  2015                 9      170.0               0.0
# 5791     4    907  2016                 9      170.0               0.0
# 5792     4    907  2017                 9      170.0               0.0
# 5793     4    907  2017                 9      170.0               0.0
# 6385    33    495  2014                 9      239.0               0.0
# 6386    33    495  2014                 9      239.0               0.0
# 6387    33    495  2014                 9      239.0               0.0
# 6388    33    495  2015                 9      239.0               0.0
# 6389    33    495  2015                 9      239.0               0.0
# 6390    33    495  2015                 9      239.0               0.0
# 6391    33    495  2015                 9      239.0               0.0
# 6392    33    495  2016                 9      239.0               0.0
# 6393    33    495  2016                 9      239.0               0.0
# 6394    33    495  2016                 9      239.0               0.0
# 6921    44    555  2014                 9      239.0               0.0
# 6922    44    555  2014                 9      239.0               0.0
# 6923    44    555  2014                 9      239.0               0.0
# 6924    44    555  2014                 9      239.0               0.0
# 6925    44    555  2015                 9      239.0               0.0
# 6926    44    555  2015                 9      239.0               0.0
# 6927    44    555  2015                 9      239.0               0.0
# 6928    44    555  2015                 9      239.0               0.0
# 6929    44    555  2015                 9      239.0               0.0
# 6930    44    555  2016                 9      239.0               0.0
# 6931    44    555  2016                 9      239.0               0.0
# 6932    44    555  2016                 9      239.0               0.0
# 6933    44    555  2016                 9      239.0               0.0
# 6934    44    555  2016                 9      239.0               0.0
# 6935    44    555  2016                 9      239.0               0.0
# 6936    44    555  2016                 9      239.0               0.0
# 6937    44    555  2016                 9      239.0               0.0
# 6938    44    555  2016                 9      239.0               0.0
# 8374    45    639  2013                 9      239.0               0.0
# 8375    45    639  2014                 9      239.0               0.0
# 9850    21    768  2015                 9      239.0               0.0
# 9851    21    768  2015                 9      239.0               0.0
# 9852    21    768  2016                 9      239.0               0.0
# 9853    21    768  2016                 9      239.0               0.0
# 9854    21    768  2016                 9      239.0               0.0
# 9867     9    770  2014                 9      140.0               0.0
# 9868     9    770  2014                 9      140.0               0.0
# 9869     9    770  2015                 9      140.0               0.0
# 9870     9    770  2015                 9      140.0               0.0
# 9871     9    770  2016                 9      140.0               0.0
# 9872     9    770  2016                 9      140.0               0.0
#
#       Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 539                   2              2              2.0               50
# 540                   2              2              2.0               50
# 541                   2              2              2.0               50
# 1680                  2              2              4.0               57
# 1681                  2              2              4.0               57
# 1682                  2              2              4.0               57
# 4705                  2              2              4.0               50
# 4706                  2              2              4.0               50
# 4785                  2              2              4.0               50
# 4789                  2              2              4.0               50
# 4798                  2              2              4.0               50
# 5790                  2              3              4.0               57
# 5791                  2              3              4.0               57
# 5792                  2              3              4.0               57
# 5793                  2              3              4.0               57
# 6385                  2              2              4.0               50
# 6386                  2              2              4.0               50
# 6387                  2              2              4.0               50
# 6388                  2              2              4.0               50
# 6389                  2              2              4.0               50
# 6390                  2              2              4.0               50
# 6391                  2              2              4.0               50
# 6392                  2              2              4.0               50
# 6393                  2              2              4.0               50
# 6394                  2              2              4.0               50
# 6921                  2              3              4.0               30
# 6922                  2              3              4.0               35
# 6923                  2              0              4.0               30
# 6924                  2              3              4.0               30
# 6925                  2              3              4.0               35
# 6926                  2              0              4.0               35
# 6927                  2              0              4.0               30
# 6928                  2              0              4.0               30
# 6929                  2              3              4.0               35
# 6930                  2              0              4.0               35
# 6931                  2              0              4.0               35
# 6932                  2              0              4.0               30
# 6933                  2              3              4.0               35
# 6934                  2              0              4.0               35
# 6935                  2              0              4.0               35
# 6936                  2              0              4.0               30
# 6937                  2              0              4.0               30
# 6938                  2              3              4.0               35
# 8374                  2              2              4.0                0
# 8375                  2              2              4.0                0
# 9850                  2              2              4.0                0
# 9851                  2              2              4.0                0
# 9852                  2              2              4.0                0
# 9853                  2              2              4.0                0
# 9854                  2              2              4.0                0
# 9867                  2              2              4.0               50
# 9868                  2              2              4.0               50
# 9869                  2              2              4.0               50
# 9870                  2              2              4.0               50
# 9871                  2              2              4.0               50
# 9872                  2              2              4.0               50
#
#       Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 539              0              0          108       122         819   31800
# 540              0              0          103       121         819   31800
# 541              0              0          103       121         819   31800
# 1680             0              2           82        85         617   41450
# 1681             0              2           82        85         617   41450
# 1682             0              2           82        85         617   39900
# 4705             0              2          105       132        2202   36625
# 4706             0              2          105       132        2202   36625
# 4785             0              2           99       110        5657   29170
# 4789             0              2           99       110        5657   29170
# 4798             0              2           99       110        5657   29120
# 5790             0              2          111       137        3916   42400
# 5791             0              2          111       137        3916   42400
# 5792             0              2          111       137        3916   42400
# 5793             0              2          106       129        3916   43600
# 6385             0              2          101       126        2009   35020
# 6386             0              2          101       126        2009   32000
# 6387             0              2          101       126        2009   28980
# 6388             0              2          101       126        2009   32100
# 6389             0              2          101       126        2009   35120
# 6390             0              2          101       126        2009   29010
# 6391             0              2          101       126        2009   32000
# 6392             0              2          101       126        2009   29010
# 6393             0              2          101       124        2009   34200
# 6394             0              2          101       124        2009   36790
# 6921             1             14           90        88        1391   79900
# 6922             1             14           97        94        1391   69900
# 6923             1             14           94        86        1391  104500
# 6924             1             14           90        88        1391   93400
# 6925             1             14           97        94        1391   69900
# 6926             1             14          102       101        1391   75000
# 6927             1             14          106        95        1391   85000
# 6928             1             14           98        89        1391  105000
# 6929             1             14           90        88        1391   80000
# 6930             1             14          105       102        1391   79500
# 6931             1             14          101        98        1391   66000
# 6932             1             14          105        92        1391  134500
# 6933             1             14          100        97        1391   74500
# 6934             1             14          107       101        1391   71000
# 6935             1             14          102       101        1391   75000
# 6936             1             14          107       101        1391   89500
# 6937             1             14          100        91        1391  112000
# 6938             1             14           90        88        1391   70000
# 8374             2              3           74        78        2031   49800
# 8375             2              3           74        78        2031   49800
# 9850             0             15           92       120        1720   35700
# 9851             0             15           92       120        1720   33700
# 9852             0             15           92       120        1720   33950
# 9853             0             15           92       120        1720   31950
# 9854             0             15           92       120        1720   35950
# 9867             0              2          109       128        1385   26685
# 9868             0              2          109       128        1385   27010
# 9869             0              2          109       128        1385   25170
# 9870             0              2          109       128        1385   25560
# 9871             0              2          109       128        1385   25510
# 9872             0              2          109       128        1385   25120

# %%
data.loc[data['Engine Cylinders']>max_limit,['Engine Cylinders']]=np.median(data['Engine Cylinders'])
data.loc[data['Engine Cylinders']<min_limit,['Engine Cylinders']]=np.median(data['Engine Cylinders'])

# %%
data.loc[data['Engine Cylinders']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Engine Cylinders']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#Transmission Type
IQR=stats.iqr(data['Transmission Type'],interpolation="midpoint")
IQR
# Out:
# 0.0

# %%
Q1=data['Transmission Type'].quantile(0.25)
Q3=data['Transmission Type'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (1.0, 1.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['Transmission Type']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Transmission Type']<min_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 296      13     22  2002                 9      400.0               8.0
# 297      13     22  2002                 9      400.0               8.0
# 299      13     22  2003                 9      400.0               8.0
# 301      13     22  2003                 9      400.0               8.0
# 302      13     22  2004                 9      400.0               8.0
# ...     ...    ...   ...               ...        ...               ...
# 11896     4    898  2014                 9      335.0               6.0
# 11898     4    898  2015                 9      300.0               6.0
# 11899     4    898  2015                 9      335.0               6.0
# 11900     4    898  2016                 9      300.0               6.0
# 11902     4    898  2016                 9      335.0               6.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 296                    0              3              2.0               30
# 297                    0              3              2.0               30
# 299                    0              3              2.0               30
# 301                    0              3              2.0               30
# 302                    0              3              2.0               30
# ...                  ...            ...              ...              ...
# 11896                  0              3              2.0               64
# 11898                  0              3              2.0               64
# 11899                  0              3              2.0               64
# 11900                  0              3              2.0               64
# 11902                  0              3              2.0               64
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 296               0              8           15        10        2774  150694
# 297               0              6           15        10        2774  170829
# 299               0              8           15        10        2774  154090
# 301               0              6           15        10        2774  176287
# 302               0              8           15        10        2774  157767
# ...             ...            ...          ...       ...         ...     ...
# 11896             0              6           24        17        3916   65800
# 11898             0              6           24        17        3916   56950
# 11899             0              6           24        17        3916   65800
# 11900             0              6           24        17        3916   57500
# 11902             0              6           24        17        3916   66350
#
# [553 rows x 16 columns]

# %%
data.loc[data['Transmission Type']>max_limit,['Transmission Type']]=np.median(data['Transmission Type'])
data.loc[data['Transmission Type']<min_limit,['Transmission Type']]=np.median(data['Transmission Type'])

# %%
data.loc[data['Transmission Type']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Transmission Type']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#highway MPG
IQR=stats.iqr(data['highway MPG'],interpolation="midpoint")
IQR
# Out:
# 8.0

# %%
Q1=data['highway MPG'].quantile(0.25)
Q3=data['highway MPG'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (10.0, 42.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['highway MPG']>max_limit]
# Out:
#       Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 135      4     12  2015                 9      180.0               4.0
# 140      4     12  2015                 9      180.0               4.0
# 142      4     12  2015                 9      180.0               4.0
# 539     12     39  2015                 9      239.0               6.0
# 540     12     39  2016                 9      239.0               6.0
# ...    ...    ...   ...               ...        ...               ...
# 9868     9    770  2014                 9      140.0               6.0
# 9869     9    770  2015                 9      140.0               6.0
# 9870     9    770  2015                 9      140.0               6.0
# 9871     9    770  2016                 9      140.0               6.0
# 9872     9    770  2016                 9      140.0               6.0
#
#       Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 135                   1              3              4.0               24
# 140                   1              0              4.0               24
# 142                   1              0              4.0               24
# 539                   1              2              2.0               50
# 540                   1              2              2.0               50
# ...                 ...            ...              ...              ...
# 9868                  1              2              4.0               50
# 9869                  1              2              4.0               50
# 9870                  1              2              4.0               50
# 9871                  1              2              4.0               50
# 9872                  1              2              4.0               50
#
#       Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 135              2             14           45        32        3916  39000
# 140              2             15           43        31        3916  43450
# 142              2             14           43        31        3916  41000
# 539              0              0          108       122         819  31800
# 540              0              0          103       121         819  31800
# ...            ...            ...          ...       ...         ...    ...
# 9868             0              2          109       128        1385  27010
# 9869             0              2          109       128        1385  25170
# 9870             0              2          109       128        1385  25560
# 9871             0              2          109       128        1385  25510
# 9872             0              2          109       128        1385  25120
#
# [182 rows x 16 columns]

# %%
data.loc[data['highway MPG']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['highway MPG']>max_limit,['highway MPG']]=np.median(data['highway MPG'])

# %%
data.loc[data['highway MPG']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#city mpg
IQR=stats.iqr(data['city mpg'],interpolation="midpoint")
IQR
# Out:
# 6.0

# %%
Q1=data['city mpg'].quantile(0.25)
Q3=data['city mpg'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (7.0, 31.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['city mpg']>max_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 135       4     12  2015                 9      180.0               4.0
# 146       4     12  2016                 9      180.0               4.0
# 161       4     12  2017                 9      180.0               4.0
# 539      12     39  2015                 9      239.0               6.0
# 540      12     39  2016                 9      239.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 10792    29    827  2008                 9      133.0               4.0
# 10795    29    827  2008                 9      133.0               4.0
# 10796    29    827  2009                 9      177.0               4.0
# 10797    29    827  2009                 9      177.0               4.0
# 11810    45    892  2017                 9      106.0               4.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 135                    1              3              4.0               24
# 146                    1              3              4.0               24
# 161                    1              3              4.0               24
# 539                    1              2              2.0               50
# 540                    1              2              2.0               50
# ...                  ...            ...              ...              ...
# 10792                  1              2              4.0               15
# 10795                  1              2              4.0               15
# 10796                  1              2              4.0               15
# 10797                  1              2              4.0               15
# 11810                  1              2              4.0                0
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 135               2             14           25        32        3916  39000
# 146               2             14           42        32        3916  39850
# 161               2             14           42        32        3916  40250
# 539               0              0           25       122         819  31800
# 540               0              0           25       121         819  31800
# ...             ...            ...          ...       ...         ...    ...
# 10792             0              3           30        34         586  27995
# 10795             0              3           30        34         586  25485
# 10796             0              3           31        34         586  29175
# 10797             0              3           31        34         586  31695
# 11810             0             14           40        32        2031  17050
#
# [305 rows x 16 columns]

# %%
data.loc[data['city mpg']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['city mpg']>max_limit,['city mpg']]=np.median(data['city mpg'])

# %%
data.loc[data['city mpg']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#Popularity
IQR=stats.iqr(data['Popularity'],interpolation="midpoint")
IQR
# Out:
# 1460.0

# %%
Q1=data['Popularity'].quantile(0.25)
Q3=data['Popularity'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (-1641.0, 4199.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['Popularity']>max_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1331     14    107  2015                 9      135.0               6.0
# 1332     14    107  2015                 9      135.0               6.0
# 1333     14    107  2015                 9      155.0               6.0
# 1334     14    107  2015                 9      135.0               6.0
# 1335     14    107  1996                 9      140.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11443    14    865  2003                 9      200.0               6.0
# 11444    14    865  2003                 9      200.0               6.0
# 11445    14    865  2003                 9      200.0               6.0
# 11446    14    865  2003                 9      200.0               6.0
# 11447    14    865  2003                 9      200.0               6.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 1331                   1              3              3.0                0
# 1332                   1              3              3.0                0
# 1333                   1              0              3.0                0
# 1334                   1              3              3.0                0
# 1335                   1              3              3.0                0
# ...                  ...            ...              ...              ...
# 11443                  1              2              4.0                0
# 11444                  1              2              4.0                0
# 11445                  1              2              4.0                0
# 11446                  1              2              4.0                0
# 11447                  1              2              4.0                0
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 1331              2              4           22        16        5657   2000
# 1332              2             11           22        15        5657   2000
# 1333              1             11           18        14        5657   2000
# 1334              1             11           22        15        5657   2000
# 1335              2             11           21        15        5657   2000
# ...             ...            ...          ...       ...         ...    ...
# 11443             2             11           22        16        5657  23070
# 11444             2             11           22        16        5657  26315
# 11445             2             11           22        16        5657  29230
# 11446             2             11           22        16        5657  34825
# 11447             2             11           22        16        5657  31835
#
# [825 rows x 16 columns]

# %%
data.loc[data['Popularity']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['Popularity']>max_limit,['Popularity']]=np.median(data['Popularity'])

# %%
data.loc[data['Popularity']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#MSRP
IQR=stats.iqr(data['MSRP'],interpolation="midpoint")
IQR
# Out:
# 21433.0

# %%
Q1=data['MSRP'].quantile(0.25)
Q3=data['MSRP'].quantile(0.75)
min_limit=Q1-1.5*IQR
max_limit=Q3+1.5*IQR
min_limit,max_limit
# Out:
# (-10550.0, 75182.0)

# %%
#check if any outliers present less than min limit & greater than max limit
data.loc[data['MSRP']>max_limit]
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 294      13     22  2002                 9      400.0               8.0
# 295      13     22  2002                 9      400.0               8.0
# 296      13     22  2002                 9      400.0               8.0
# 297      13     22  2002                 9      400.0               8.0
# 298      13     22  2003                 9      400.0               8.0
# ...     ...    ...   ...               ...        ...               ...
# 11736     8    884  2008                 9      320.0               8.0
# 11737     8    884  2009                 9      320.0               8.0
# 11903     4    900  2001                 9      394.0               8.0
# 11904     4    900  2002                 9      394.0               8.0
# 11905     4    900  2003                 9      394.0               8.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Market Category  \
# 294                    1              3              2.0               30
# 295                    1              3              2.0               30
# 296                    1              3              2.0               30
# 297                    1              3              2.0               30
# 298                    1              3              2.0               30
# ...                  ...            ...              ...              ...
# 11736                  1              3              2.0               63
# 11737                  1              3              2.0               63
# 11903                  1              3              2.0               32
# 11904                  1              3              2.0               32
# 11905                  1              3              2.0               32
#
#        Vehicle Size  Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 294               0              6           15        10        2774  160829
# 295               0              8           15        10        2774  140615
# 296               0              8           15        10        2774  150694
# 297               0              6           15        10        2774  170829
# 298               0              6           15        10        2774  165986
# ...             ...            ...          ...       ...         ...     ...
# 11736             0              6           24        15        1624   85650
# 11737             0              6           24        15        1624   86215
# 11903             0              6           19        12        3916  128000
# 11904             0              6           19        12        3916  130000
# 11905             0              6           19        12        3916  131500
#
# [960 rows x 16 columns]

# %%
data.loc[data['MSRP']<min_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
data.loc[data['MSRP']>max_limit,['MSRP']]=np.median(data['MSRP'])

# %%
data.loc[data['MSRP']>max_limit]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
#boxplot for outlier detection
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %% [markdown]
# # Model Creation

# %%
y = data['MSRP']                   #y is the dependent variable to be predicted
x = data.drop(['MSRP'],axis =1)    #x is the independent variables
#importing the sklearn library for splitting the dataset to train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.25,random_state = 42)
from sklearn.ensemble import RandomForestRegressor
rf_rgr=RandomForestRegressor(n_estimators=100,random_state=42)
rf_rgr.fit(x_train,y_train)
y_pred_rf=rf_rgr.predict(x_test)
#Evaluation metrics
from sklearn.metrics import r2_score
print('r2 score = ',r2_score(y_test,y_pred_rf))
# Out:
# r2 score =  0.9114323862628682

# %%
from sklearn.ensemble import AdaBoostRegressor
ada_rgr=AdaBoostRegressor(n_estimators=10,random_state=0)
ada_rgr.fit(x_train,y_train)

y_pred_ada=ada_rgr.predict(x_test)
from sklearn.metrics import mean_squared_error
print('MSE = ',mean_squared_error(y_test,y_pred_ada))


from sklearn.metrics import r2_score
print('r2 score = ',r2_score(y_test,y_pred_ada))
# Out:
# MSE =  99176546.22374009
# r2 score =  0.5945676905806895

# %%
from sklearn.tree import DecisionTreeRegressor
dt_rgr = DecisionTreeRegressor(random_state=0)
dt_rgr.fit(x_train,y_train)

y_pred_dt=dt_rgr.predict(x_test)
from sklearn.metrics import mean_squared_error
print('MSE = ',mean_squared_error(y_test,y_pred_dt))


from sklearn.metrics import r2_score
print('r2 score = ',r2_score(y_test,y_pred_dt))
# Out:
# MSE =  29753329.32669189
# r2 score =  0.8783688131806867

# %%
#here Random Forest Regressor model can be used for better price prediction..it have better r2 score compared to other models.
