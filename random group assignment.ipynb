# %%
import random

partisipants=["name 1","name 2","name 3","name 4",\
              "name 5","name 6","name 7","name 8",\
              "name 9","name 10","name 11","name 12",\
              "name 13","name 14","name 15","name 16"]



part_copy= partisipants

random.shuffle(part_copy)

print(part_copy)

# %%
group_size_max= 5

group_size=random.randint(2, group_size_max)
print(group_size)

# %%
#group=0
#group_size=4

for part in part_copy:
    
    part = part_copy[:group_size]
    del part_copy[0:group_size]
    
    print(part_copy)
    print(group_size)
    print(part)

# %%
glossary = {}

while True:
    new_key = input("Please enter term: ")
    new_value = input("Please enter definition: ")
    glossary[new_key] = new_value
    more_entries = input("Do you want to add another entry? (y/n) ")
    if more_entries != "y":
        break
        
keys = list(glossary.keys())
keys.sort()

for key in keys:
    print(f"{key}: {glossary[key]}")

# %%
def group_size(2, group_size_max):
    group_size=random.randint(2, group_size_max)
    return group_size

# %%
coff_groups={}
group_num=1

group_size_max= 5

group_allocation = False

while group_allocation is not True :
    
    people_left=len(part_copy)
    group_size= group_size(2, group_size_max)
    
    
    if people_left > group_size:
        
        if people_left% group_size != 1:
            group_key = "Group " + str(group_num)
            coff_part= part_copy[:group_size]
            del part_copy[0:group_size]
        
        else:
            group_key = "Group " + str(group_num)
            coff_part= part_copy[:people_left]
            del part_copy[0:people_left]
    
    if people_left == 1:
        
            
    
    
        
    
    

    
    
    
    
    
    
    
    coff_groups[group_key] = coff_part
    group_num +=1
 
    
    print(coff_groups)
    
    if group_size >5:
        break

# %%
x=3%6
print(x)

# %%
import random


people = ["Bob", "Charlie", "Dave", "Eve", "Frank", "Grace", "Hannah", "Isaac", "Julie"]

random.shuffle(people)

min_group_size = 2
max_group_size = 5
groups = []

while len(people) > 0:
    group_size = random.randint(min_group_size, max_group_size)
    # If there are not enough people left to form a group of the chosen size, 
    # set the group size to the remaining number of people
    
    if len(people) < group_size:
        group_size = len(people)

    # Take the first group_size people from the list of people and add them to a new group
    group = people[:group_size]

    # Remove the people in the group from the list of people
    people = people[group_size:]

    # Add the group to the list of groups
    groups.append(group)

    #print("Random groups of people:")
    
#for i, group in enumerate(groups):
#    print(f"Group {i+1}: {', '.join(group)}")

print(groups)
# Out:
# [['Julie', 'Eve', 'Charlie', 'Hannah'], ['Grace', 'Isaac', 'Frank'], ['Bob', 'Dave']]

# %%
import random


people = ["name 1","name 2","name 3","name 4",\
              "name 5","name 6","name 7","name 8",\
              "name 9","name 10","name 11","name 12",\
              "name 13","name 14","name 15","name 16"]

conversation_starters = ["Start 1", "Start 2", "Start 3", "Start 4",\
                         "Start 5", "Start 6", "Start 7", "Start 8"]

jokes = ["joke 1", "joke 2","joke 3","joke 4","joke 5","joke 6",\
         "joke 7","joke 8","joke 9","joke 10","joke 11","joke 12" ] 



random.shuffle(people)

min_group_size = 2
max_group_size = 5
group_num = 1

groups = {}

while len(people) > 0:
    group_value =[] 
    group_size = random.randint(min_group_size, max_group_size)
    
    # If there are not enough people left to form a group of the chosen size, 
    # set the group size to the remaining number of people
    
    group_left = len(people) - group_size
    
    if group_left == 1:
        continue
        
    if len(people) < group_size:
        group_size = len(people)

    # Take the first group_size people from the list of people and add them to a new group
    group = people[:group_size]

    # Remove the people in the group from the list of people
    people = people[group_size:]

    # Add the group to the list of groups
    group_value.append(group)

    selected_starter = random.choice(conversation_starters) #picks an random conversation starter
    selected_joke = random.choice(jokes) # picks an random joke
    
    group_value.append(selected_starter) # adds the conversation starter to the group
    group_value.append(selected_joke) # adds joke to group

    group_key = "Group " + str(group_num)

    groups[group_key] = group_value
    
    group_num += 1
    
 
    
    
    #print("Random groups of people:")
    
for i, group in enumerate(groups):
    print(f"Group {i+1}: {groups[group]}")
# Out:
# loop werkt
# Group 1: [['name 8', 'name 2'], 'Start 2', 'joke 8']
# Group 2: [['name 5', 'name 1'], 'Start 8', 'joke 6']
# Group 3: [['name 11', 'name 6'], 'Start 8', 'joke 2']
# Group 4: [['name 12', 'name 9', 'name 15', 'name 7'], 'Start 5', 'joke 9']
# Group 5: [['name 13', 'name 14'], 'Start 4', 'joke 12']
# Group 6: [['name 4', 'name 3'], 'Start 7', 'joke 8']
# Group 7: [['name 16', 'name 10'], 'Start 4', 'joke 12']

# %%
{'Group 1': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'], ['name 12', 'name 11'], ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'], ['name 15', 'name 14', 'name 6', 'name 8']], 
 'Group 2': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'], ['name 12', 'name 11'], ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'], ['name 15', 'name 14', 'name 6', 'name 8']], 
 'Group 3': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'], ['name 12', 'name 11'], ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'], ['name 15', 'name 14', 'name 6', 'name 8']], 
 'Group 4': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'], ['name 12', 'name 11'], ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'], ['name 15', 'name 14', 'name 6', 'name 8']]}
# Out:
# {'Group 1': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'],
#   ['name 12', 'name 11'],
#   ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'],
#   ['name 15', 'name 14', 'name 6', 'name 8']],
#  'Group 2': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'],
#   ['name 12', 'name 11'],
#   ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'],
#   ['name 15', 'name 14', 'name 6', 'name 8']],
#  'Group 3': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'],
#   ['name 12', 'name 11'],
#   ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'],
#   ['name 15', 'name 14', 'name 6', 'name 8']],
#  'Group 4': [['name 3', 'name 16', 'name 4', 'name 7', 'name 1'],
#   ['name 12', 'name 11'],
#   ['name 10', 'name 5', 'name 9', 'name 2', 'name 13'],
#   ['name 15', 'name 14', 'name 6', 'name 8']]}

# %%
{'Group 1': [['name 7', 'name 2', 'name 5'], 'Start 1', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 13', 'name 1', 'name 3', 'name 12', 'name 9'], 'Start 4', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 10', 'name 16', 'name 6', 'name 11'], 'Start 2', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 4', 'name 15', 'name 8', 'name 14'], 'Start 8', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12']], 
 'Group 2': [['name 7', 'name 2', 'name 5'], 'Start 1', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 13', 'name 1', 'name 3', 'name 12', 'name 9'], 'Start 4', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 10', 'name 16', 'name 6', 'name 11'], 'Start 2', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 4', 'name 15', 'name 8', 'name 14'], 'Start 8', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12']], 
 'Group 3': [['name 7', 'name 2', 'name 5'], 'Start 1', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 13', 'name 1', 'name 3', 'name 12', 'name 9'], 'Start 4', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 10', 'name 16', 'name 6', 'name 11'], 'Start 2', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 4', 'name 15', 'name 8', 'name 14'], 'Start 8', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12']], 
 'Group 4': [['name 7', 'name 2', 'name 5'], 'Start 1', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 13', 'name 1', 'name 3', 'name 12', 'name 9'], 'Start 4', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 10', 'name 16', 'name 6', 'name 11'], 'Start 2', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12'], ['name 4', 'name 15', 'name 8', 'name 14'], 'Start 8', ['joke 1', 'joke 2', 'joke 3', 'joke 4', 'joke 5', 'joke 6', 'joke 7', 'joke 8', 'joke 9', 'joke 10', 'joke 11', 'joke 12']]
